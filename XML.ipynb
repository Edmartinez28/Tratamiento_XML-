# %%
import xml.etree.ElementTree as et
import pandas as pd 

xdata = et.parse(r"C:\Users\ASUS\Documents\UTPL\cuarto ciclo\Practicum 1.2\Semana 9\Info\Info\TASS2019_country_CR_train.xml")
xroot = xdata.getroot()

df_colums = ["tweet","tweetid","user","content","date","lang","sentiment"] 
rows = []

for node in xroot: 
    s_tweet = node.attrib.get("tweet")
    s_tweetid = node.find("tweetid").text if node is not None else None
    s_user = node.find("user").text if node is not None else None
    s_content = node.find("content").text if node is not None else None
    s_date = node.find("date").text if node is not None else None
    s_lang = node.find("lang").text if node is not None else None
    s_sentiment = node.find("sentiment").find("polarity").find("value").text if node is not None else None
    
    rows.append({"tweet": s_tweet, "tweetid": s_tweetid, 
                 "user": s_user, "content": s_content,
                 "date": s_date, "lang": s_lang
                ,"sentiment":s_sentiment})
    
out_df = pd.DataFrame(rows, columns = df_colums)

# %%
out_df # Datos convetidos en DataFrame
# Out:
#     tweet             tweetid                user  \
# 0    None  768225400254111744            14628107
# 1    None  770077064833671168           713600676
# 2    None  771207534342320128           120940293
# 3    None  771900763987513345          2827444381
# 4    None  772550560998301697            60878511
# ..    ...                 ...                 ...
# 772  None  814853214050906112           311102472
# 773  None  815439552038977537           119492787
# 774  None  817864316372348928          4878793919
# 775  None  817069708927266816  722185474182254598
# 776  None  817032173689696257           205417315
#
#                                                content  \
# 0                   @NoilyMV yo soy totalmente puntual
# 1    @SandraCauffman Hola Sandrita. No le habia des...
# 2    Si andan haciendo eso mejor se quedaran callad...
# 3                       Que pereza quiero choco banano
# 4    @robertobrenes Bueno, no es tanto lo mayor com...
# ...

# %%
rows # Datos convertidos en JSON
# Out:
# [{'tweet': None,
#   'tweetid': '768225400254111744',
#   'user': '14628107',
#   'content': '@NoilyMV yo soy totalmente puntual',
#   'date': 'Tue Aug 23 23:16:23 +0000 2016',
#   'lang': 'es',
#   'sentiment': 'NONE'},
#  {'tweet': None,
#   'tweetid': '770077064833671168',
#   'user': '713600676',
#   'content': '@SandraCauffman Hola Sandrita. No le habia deseado un feliz dia de la madre, tarde pero seguro.¿ Sabe usted si Juno ha tomado mas fotos ?',
#   'date': 'Mon Aug 29 01:54:14 +0000 2016',
#   'lang': 'es',
#   'sentiment': 'P'},
#  {'tweet': None,
#   'tweetid': '771207534342320128',
#   'user': '120940293',
#   'content': 'Si andan haciendo eso mejor se quedaran calladitas jaja pero así se están quemando ellas mismas e insinuando que son unas metidas',
#   'date': 'Thu Sep 01 04:46:19 +0000 2016',
#   'lang': 'es',
#   'sentiment': 'N'},
#  {'tweet': None,
#   'tweetid': '771900763987513345',
#   'user': '2827444381',
#   'content': 'Que pereza quiero choco banano',
# ...

# %%
csv_data = out_df.to_csv()
csv_data
# Out:
# ',tweet,tweetid,user,content,date,lang,sentiment\r\n0,,768225400254111744,14628107,@NoilyMV yo soy totalmente puntual,Tue Aug 23 23:16:23 +0000 2016,es,NONE\r\n1,,770077064833671168,713600676,"@SandraCauffman Hola Sandrita. No le habia deseado un feliz dia de la madre, tarde pero seguro.¿ Sabe usted si Juno ha tomado mas fotos ?",Mon Aug 29 01:54:14 +0000 2016,es,P\r\n2,,771207534342320128,120940293,Si andan haciendo eso mejor se quedaran calladitas jaja pero así se están quemando ellas mismas e insinuando que son unas metidas,Thu Sep 01 04:46:19 +0000 2016,es,N\r\n3,,771900763987513345,2827444381,Que pereza quiero choco banano,Sat Sep 03 02:40:58 +0000 2016,es,N\r\n4,,772550560998301697,60878511,"@robertobrenes Bueno, no es tanto lo mayor como cuánto de campo sea usted. Sos cartaguito en cada aspecto de tu vida, por lo visto.",Sun Sep 04 21:43:01 +0000 2016,es,N\r\n5,,772594807357124608,761015519646363648,Pasé todo el día buscando mi Baby Lips y lo acabo de encontrar. Estaba en la m
# ...
